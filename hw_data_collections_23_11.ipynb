# %% [markdown]
# <a href="https://colab.research.google.com/github/olyadiya/MA-intro-to-python/blob/main/hw_data_collections_23_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Синтаксис

# %% [markdown]
# **Задача 1**
#
# Создайте список mixed_data, содержащий:
#
# - 3 числа (int)
# - 2 строки (str)
# - 1 вложенный список
# - 1 кортеж
# - 1 множество
#
# Добавьте в конец списка число 123
#
# Удалите вторую строку из списка
#
# Вставьте строку "inserted" на позицию 2
#
# Выведите итоговый список

# %%
mixed_data = [27, 44, 78, "love this hw", "i am delusional", (5, 6), [], {10, 11, 12}]
mixed_data.append(int(123))
mixed_data.insert(2, "inserted")
print(mixed_data)
# Out:
# [27, 44, 'inserted', 78, 'love this hw', 'i am delusional', (5, 6), [], {10, 11, 12}, 123]

# %% [markdown]
# **Задача 2**
#
# Создайте кортеж user_credentials, содержащий:
#
# - Логин (строка)
#
# - Хэш пароля (строка)
#
# - Уровень доступа (целое число)
#
# Попробуйте изменить уровень доступа (должна возникнуть ошибка)
#
# Напишите комментарий, почему кортеж подходит для хранения таких данных

# %%
user_credentials = ("olyadiya", "12345678", 4)
user_credentials[2] = 2
print(user_credentials) #данные кортежа нельзя поменять после создания
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2719152740.py in <cell line: 0>()
#       1 user_credentials = ("olyadiya", "12345678", 4)
# ----> 2 user_credentials[2] = 2
#       3 print(user_credentials)
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# **Задача 3**
#
# Дано:

# %%
tags1 = {"python", "ml", "data"}
tags2 = {"ml", "nlp", "deeplearning"}

# %% [markdown]
# Найдите:
#
# - Общие теги (пересечение)
#
# - Все уникальные теги (объединение)
#
# - Теги, которые есть в tags1, но нет в tags2

# %%
tags1 = {"python", "ml", "data"}
tags2 = {"ml", "nlp", "deeplearning"}
tags_common = tags1&tags2
tags_unique = tags1|tags2
tags_dif = tags1 - tags2
print(tags_common, tags_dif, tags_unique)
# Out:
# {'ml'} {'python', 'data'} {'python', 'deeplearning', 'ml', 'nlp', 'data'}

# %% [markdown]
# ### Фильтрация и обработка текстовых данных

# %% [markdown]
# 1. Установите nltk и загрузите стоп-слова для русского и английского языков
#
# *Уже выполнено: просто запустите эту ячейку*

# %%
import nltk
import string
from nltk.corpus import stopwords

# Установка nltk и загрузка стоп-слов
nltk.download('stopwords')

# Загрузка стоп-слов для русского и английского языков
stopwords_english = stopwords.words('english')
stopwords_russian = stopwords.words('russian')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# 2. Конвертируйте списки слов на русском и английском, приведите их к виду множства `set`
#
# *Это стандартная операция: работа со стоп-словами всегда начинается с фильтрации, удаления дубликатов*

# %%
stopwords_english = set(stopwords_english)
stopwords_russian = set(stopwords_russian)

# %% [markdown]
# 3. Выведите на экран первые 10 стоп-слов из двух списков
#
# *Подумайте, как это сделать, ведь `set` нельзя индексировать, а созданный список слов нельзя перезаписывать*

# %%
stopwords_english_first10 = list(stopwords.words('english')[:10])
stopwords_russian_first10 = list(stopwords.words('russian')[:10])

# %% [markdown]
# 4. Дан текст

# %%
# Исходный текст
text = """
This is a sample text for processing. It contains some stopwords and important words.
Этот текст содержит как английские, так и русские слова, включая стоп-слова.
"""

# %% [markdown]
# Допишите функцию в указанном плейсхолдере
#
# Функция:
#
# - удаляет знаки препинания
# - разбивает текст на слова
# - приводит текст к нижнему регистру

# %%
# Токенизация текста на слова
def tokenize_text(text):
    translator = str.maketrans('', '', string.punctuation)
    text_clean = text.translate(translator).lower()
    words = text_clean.split()
    return words

# %% [markdown]
# Применим нашу функцию к тексту

# %%
# Токенизируем текст
words = tokenize_text(text)

# %% [markdown]
# Выведите на экран список токенов и общее количество слов

# %%
print("Список токенов:")
print(words)
print(f"Общее количество слов: {len(words)}")
# Out:
# Список токенов:
# ['this', 'is', 'a', 'sample', 'text', 'for', 'processing', 'it', 'contains', 'some', 'stopwords', 'and', 'important', 'words', 'этот', 'текст', 'содержит', 'как', 'английские', 'так', 'и', 'русские', 'слова', 'включая', 'стопслова']
# Общее количество слов: 25

# %% [markdown]
# 5. Произведите фильтрацию стоп-слов для двух языков
#
# - Создайте пустой список
# - Запустите цикл for (`for word in words`, для каждого слова в списке слов)
# - Если слова нет в списке стоп-слов
# - Сделайте `append` в созданный список
#
# *Допишите функцию*

# %%
# Фильтрация стоп-слов для обоих языков
def filter_stopwords(words, stopwords_set):
    filtered_words = []
    for word in words:
        if word not in stopwords_set:
            filtered_words.append(word)

    return filtered_words

# %% [markdown]
# 6. Примените операции со множествами

# %%
all_stopwords = stopwords_english|stopwords_russian
### ваш код здесь ###

# %% [markdown]
# 7. Применим нашу функцию для фильтрации данных
#
# *В переменной `all_stopwords` должен быть результат объединения множеств из пункта 6*

# %%
# Фильтруем стоп-слова
meaningful_words = filter_stopwords(words, all_stopwords)

# %% [markdown]
# Выведите на экран список `meaningful_words`, а также длину этого списка

# %%
print("Значимые слова после фильтрации:")
print(meaningful_words)
print(f"Количество значимых слов: {len(meaningful_words)}")
# Out:
# Значимые слова после фильтрации:
# ['sample', 'text', 'processing', 'contains', 'stopwords', 'important', 'words', 'текст', 'содержит', 'английские', 'русские', 'слова', 'включая', 'стопслова']
# Количество значимых слов: 14

# %% [markdown]
# 8. Создаем множество уникальных значимых слов
#
# *Конвертируем список `meaningful_words` к виду множества*

# %%
unique_meaningful_words = set(meaningful_words)

# %% [markdown]
# Выведите на экран результат, а также длину полчившегося множества

# %%
print("Уникальные значимые слова:")
print(unique_meaningful_words)
print(f"Количество уникальных значимых слов: {len(unique_meaningful_words)}")
# Out:
# Уникальные значимые слова:
# {'текст', 'text', 'слова', 'включая', 'содержит', 'стопслова', 'important', 'processing', 'русские', 'contains', 'английские', 'words', 'sample', 'stopwords'}
# Количество уникальных значимых слов: 14

# %% [markdown]
# 9. Создайте отчет
#
# - выведите исходное количество стоп-слов на английском
# - исходное количество слов на русском
# - общее количество стоп-слов

# %%
print("ОТЧЕТ:")
print(f"Исходное количество английских стоп-слов: {len(stopwords_english)}")
print(f"Исходное количество русских стоп-слов: {len(stopwords_russian)}")
print(f"Общее количество стоп-слов: {len(all_stopwords)}")
print(f"Исходное количество слов в тексте: {len(words)}")
print(f"Количество слов после фильтрации: {len(meaningful_words)}")
print(f"Удалено стоп-слов: {len(words) - len(meaningful_words)}")
# Out:
# ОТЧЕТ:
# Исходное количество английских стоп-слов: 198
# Исходное количество русских стоп-слов: 151
# Общее количество стоп-слов: 349
# Исходное количество слов в тексте: 25
# Количество слов после фильтрации: 14
# Удалено стоп-слов: 11

# %% [markdown]
# 10. Проведите анализ результатов: какие стоп-слова были удалены из исходного текста?
#
# - создайте список для сохранения отфильтрованных слов
# - для каждого слова исходного текста (`text`)
# - если данное слово было в списке стоп-слов
# - добавляем его в созданный список
#
# *Выведите на экран отфильтрованные слова (т.е. удаленные)*

# %%
removed_words = []
for word in words:
    if word in all_stopwords:
        removed_words.append(word)

print("Удаленные стоп-слова:")
print(removed_words)
print(f"Количество удаленных стоп-слов: {len(removed_words)}")
# Out:
# Удаленные стоп-слова:
# ['this', 'is', 'a', 'for', 'it', 'some', 'and', 'этот', 'как', 'так', 'и']
# Количество удаленных стоп-слов: 11
